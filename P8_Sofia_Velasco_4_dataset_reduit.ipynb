# %%
#Importer les modules:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer
import colorama
from colorama import Fore
from colorama import Style
import os, sys
import matplotlib
from matplotlib import cm
from matplotlib.patches import Circle, Wedge, Rectangle
from math import log10
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, f1_score, precision_score, recall_score 
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import classification_report

from imblearn.over_sampling import SMOTE 
from imblearn.over_sampling import SMOTENC

import scipy.stats as stats
import shap
import lime
from lime import lime_tabular
import random

import statsmodels.api as sm
from statsmodels.formula.api import ols


import ast
import scipy.stats as stats
import re
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import fbeta_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn import metrics
from sklearn.inspection import permutation_importance
import math
from datetime import datetime
from datetime import timedelta, date

from functools import reduce
from sklearn.preprocessing import MinMaxScaler

import pickle
from dill import dumps, loads
import dill

import os
import random
from PIL import Image
import shutil

# %%
cd Desktop\Data Science candidature\Projets\Projet 8\Data
# Out:
# C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data

# %%
### Sélection d'images random pour chaque fruit:
#5 pour le Training set.
#3 pour le Test set.
#3 pour le validation set.

#En fait, on travaillera avec une base de données très réduite. On prendra en fait que quelques images par fruits car on a 
#choisi de réduire le dataset utilisé afin de ne pas dépasser les version moins chères de AWS, et être en ligne avec la 
#version test de Databricks

# %%
type=os.listdir(PATH+'/fruits-360-original-size/Training')

# %%
for m in type:
    path = PATH+'/fruits-360-original-size/Training/'+m
    names = random.choices(os.listdir(path), k=5) #----> Randomly select 5 images

    destPath= PATH+'/Train/'+m
    for name in names:
        if name:  # to skip empty lines
            fullpath = os.path.join(path, name)
            if os.path.exists(fullpath):
                print('coping:', fullpath)
                shutil.copy(fullpath, destPath)
            else:
                print('SKIPING:', fullpath)
# Out:
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Training/apple_6\r1_72.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Training/apple_6\r1_126.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Training/apple_6\r1_242.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Training/apple_6\r0_50.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Training/apple_6\r1_264.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Training/apple_braeburn_1\r0_160.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Training/apple_braeburn_1\r0_246.jpg
# ...

# %%
for m in type:
    path = PATH+'/fruits-360-original-size/Test/'+m
    names = random.choices(os.listdir(path), k=3) #----> Randomly select 5 images

    destPath= PATH+'/Test/'+m
    for name in names:
        if name:  # to skip empty lines
            fullpath = os.path.join(path, name)
            if os.path.exists(fullpath):
                print('coping:', fullpath)
                shutil.copy(fullpath, destPath)
            else:
                print('SKIPING:', fullpath)
# Out:
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Test/apple_6\r0_23.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Test/apple_6\r1_63.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Test/apple_6\r1_263.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Test/apple_braeburn_1\r0_183.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Test/apple_braeburn_1\r0_315.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Test/apple_braeburn_1\r0_163.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Test/apple_crimson_snow_1\r1_47.jpg
# ...

# %%
for m in type:
    path = PATH+'/fruits-360-original-size/Validation/'+m
    names = random.choices(os.listdir(path), k=3) #----> Randomly select 5 images

    destPath= PATH+'/Validation/'+m
    for name in names:
        if name:  # to skip empty lines
            fullpath = os.path.join(path, name)
            if os.path.exists(fullpath):
                print('coping:', fullpath)
                shutil.copy(fullpath, destPath)
            else:
                print('SKIPING:', fullpath)
# Out:
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Validation/apple_6\r1_61.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Validation/apple_6\r1_165.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Validation/apple_6\r0_289.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Validation/apple_braeburn_1\r1_161.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Validation/apple_braeburn_1\r1_189.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Validation/apple_braeburn_1\r1_257.jpg
# coping: C:\Users\'titite\Desktop\Data Science candidature\Projets\Projet 8\Data/fruits-360-original-size/Validation/apple_crimson_snow_1\r1_209.jpg
# ...
